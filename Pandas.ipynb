# %%
import pandas as pd
import math

# %% [markdown]
# ## Series Dataframe
# #### series -> 1-dimensional

# %%
series = pd.Series(["BMW","Toyota","Honda"])
colors = pd.Series(["Red","Blue","White"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# ## DataFrame -> 2-dimensional

# %%
car_data = pd.DataFrame({"Car Make":series,"Colors":colors})

# %%
car_data
# Out:
#   Car Make Colors
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv",index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### .loc & .iloc

# %% [markdown]
# #### .loc

# %%
animals = pd.Series(["snake","elephant","dog","pandas","cat","cow"],index = [4,5,8,1,7,22])
animals
# Out:
# 4        snake
# 5     elephant
# 8          dog
# 1       pandas
# 7          cat
# 22         cow
# dtype: object

# %%
animals.loc[22]      #it refers to the location of the index values
# Out:
# 'cow'

# %%
animals.loc[1]
# Out:
# 'pandas'

# %%
animals.loc[:8]
# Out:
# 4       snake
# 5    elephant
# 8         dog
# dtype: object

# %% [markdown]
# #### .iloc

# %%
animals.iloc[2]    #it refers to the position of the index started from 0 as always
# Out:
# 'dog'

# %%
animals.iloc[5]
# Out:
# 'cow'

# %%
animals.iloc[:3]
# Out:
# 4       snake
# 5    elephant
# 8         dog
# dtype: object

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#comparing the two columns
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)

# %%
car_sales["Price"].dtype
# Out:
# dtype('int32')

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"]= car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True))

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing["Odometer"] = round(car_sales_missing["Odometer"],2)

# %%
car_sales_missing
# Out:
#      Make Colour   Odometer  Doors    Price
# 0  Toyota  White  150043.00    4.0   $4,000
# 1   Honda    Red   87899.00    4.0   $5,000
# 2  Toyota   Blue   92302.67    3.0   $7,000
# 3     BMW  Black   11179.00    5.0  $22,000
# 4  Nissan  White  213095.00    4.0   $3,500
# 5  Toyota  Green   92302.67    4.0   $4,500
# 6   Honda    NaN   92302.67    4.0   $7,500
# 7   Honda   Blue   92302.67    4.0      NaN
# 8  Toyota  White   60000.00    NaN      NaN
# 9     NaN  White   31600.00    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)
car_sales_missing
# Out:
#      Make Colour   Odometer  Doors    Price
# 0  Toyota  White  150043.00    4.0   $4,000
# 1   Honda    Red   87899.00    4.0   $5,000
# 2  Toyota   Blue   92302.67    3.0   $7,000
# 3     BMW  Black   11179.00    5.0  $22,000
# 4  Nissan  White  213095.00    4.0   $3,500
# 5  Toyota  Green   92302.67    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %% [markdown]
# ## Manipulating Data - 2

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(5).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000      5
# 1   honda    Red          87899      4   5000      5
# 2  toyota   Blue          32549      3   7000      5
# 3     bmw  Black          11179      5  22000      5
# 4  nissan  White         213095      4   3500      5
# 5  toyota  Green          99213      4   4500      5
# 6   honda   Blue          45698      4   7500      5
# 7   honda   Blue          54738      4   7000      5
# 8  toyota  White          60000      4   6250      5
# 9  nissan  White          31600      4   9700      5

# %%
# Creating a column from the python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales["Total fuel used (L)"] = round(car_sales["Total fuel used (L)"],2)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5
#
#    Total fuel used  Total fuel used (L)
# 0         11253.22             11253.22
# 1          8086.71              8086.71
# 2          1627.45              1627.45
# 3          1073.18              1073.18
# ...

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0         11253.22             11253.22                 4
# 1          8086.71              8086.71                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road safety
# 0         11253.22             11253.22                 4                True
# ...

# %%
car_sales.drop("Total fuel used", axis = 1, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0             11253.22                 4                True
# 1              8086.71                 4                True
# ...

# %% [markdown]
# ## Manipulating Data - 3

# %%
# Only select 30% of data from the actual records
car_sales_shuffled = car_sales.sample(frac = 0.3)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 4  nissan  White         213095      4   3500      5             8.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 3     bmw  Black          11179      5  22000      5             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 4             18539.26                 4                True
# 6              3473.05                 4                True
# 3              1073.18                 4                True

# %%
car_sales_shuffled.reset_index(drop = True, inplace = True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  nissan  White         213095      4   3500      5             8.7
# 1   honda   Blue          45698      4   7500      5             7.6
# 2     bmw  Black          11179      5  22000      5             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0             18539.26                 4                True
# 1              3473.05                 4                True
# 2              1073.18                 4                True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000      5             7.5
# 1   honda    Red          87899      4   5000      5             9.2
# 2  toyota   Blue          32549      3   7000      5             5.0
# 3     bmw  Black          11179      5  22000      5             9.6
# 4  nissan  White         213095      4   3500      5             8.7
# 5  toyota  Green          99213      4   4500      5             4.7
# 6   honda   Blue          45698      4   7500      5             7.6
# 7   honda   Blue          54738      4   7000      5             8.7
# 8  toyota  White          60000      4   6250      5             3.0
# 9  nissan  White          31600      4   9700      5             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0             11253.22                 4                True
# 1              8086.71                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000      5             7.5
# 1   honda    Red      54936.875      4   5000      5             9.2
# 2  toyota   Blue      20343.125      3   7000      5             5.0
# 3     bmw  Black       6986.875      5  22000      5             9.6
# 4  nissan  White     133184.375      4   3500      5             8.7
# 5  toyota  Green      62008.125      4   4500      5             4.7
# 6   honda   Blue      28561.250      4   7500      5             7.6
# 7   honda   Blue      34211.250      4   7000      5             8.7
# 8  toyota  White      37500.000      4   6250      5             3.0
# 9  nissan  White      19750.000      4   9700      5             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0             11253.22                 4                True
# 1              8086.71                 4                True
# ...
